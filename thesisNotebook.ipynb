# %%
# !pip install -q pyngrok

# %%
# @title
# !python /content/flaskChatBot/flask_app/app.py
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# tokenizer_config.json: 100% 1.62k/1.62k [00:00<00:00, 9.02MB/s]
# tokenizer.model: 100% 500k/500k [00:00<00:00, 8.93MB/s]
# special_tokens_map.json: 100% 414/414 [00:00<00:00, 2.03MB/s]
# tokenizer.json: 100% 1.84M/1.84M [00:00<00:00, 17.9MB/s]
# config.json: 100% 614/614 [00:00<00:00, 3.21MB/s]
# model.safetensors.index.json: 100% 26.8k/26.8k [00:00<00:00, 68.5MB/s]
# ...
# model-00001-of-00002.safetensors:   0% 0.00/9.98G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0% 10.5M/9.98G [00:00<01:42, 97.2MB/s]
# ...
